# %%
def add(a,b):
    c = a + b
    return c

import numpy as np
X=np.linspace(1,10,10)
def sum_list(values):
    total =0
    for num in X:
        total  = add(total,num)
    return total

sum=sum_list(X)
print(sum)
